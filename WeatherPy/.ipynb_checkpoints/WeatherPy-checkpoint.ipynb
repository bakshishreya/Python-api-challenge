# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime
from pprint import pprint
import scipy.stats as st

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# List for holding reponse information
lat = []
temp = []
temp_max = []
humidity = []
wind_speed = []
lon = []
date = []
country = []
cloudiness = []


# Loop through the list of cities and request for data on each
print("Beginning Data Retrieval")
print("--------------------------------------------")
count = 0
set = 1
for idx, city in enumerate(cities):
    count = count + 1
    # To avoid api call rate limits, get city weather data for 50 cities,
    # then sleep for 5 seconds, and then continue with next 50 cities and so on...
    if count == 51:
        count = 1
        set = set + 1
        time.sleep(5)
    print(f"Processing Record {count} of Set {set} | {city}")
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
        date.append(response['dt'])
        country.append(response['sys']['country'])
        cloudiness.append(response['clouds']['all'])
    except KeyError:
        print("City not found. Skipping...")
        lat.append(np.nan)
        lon.append(np.nan)
        temp.append(np.nan)
        temp_max.append(np.nan)
        humidity.append(np.nan)
        wind_speed.append(np.nan)
        date.append(np.nan)
        country.append(np.nan)
        cloudiness.append(np.nan)
print("------------------------------------------------")
print("Data Retrieval Complete")
print("------------------------------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | glencoe
# Processing Record 3 of Set 1 | severo-kurilsk
# Processing Record 4 of Set 1 | carnarvon
# Processing Record 5 of Set 1 | trikala
# Processing Record 6 of Set 1 | cabo san lucas
# Processing Record 7 of Set 1 | avarua
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | saskylakh
# Processing Record 10 of Set 1 | bud
# Processing Record 11 of Set 1 | zhezkazgan
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | georgetown
# Processing Record 14 of Set 1 | diamantino
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | akyab
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | noshiro
# Processing Record 20 of Set 1 | almaznyy
# Processing Record 21 of Set 1 | mangrol
# Processing Record 22 of Set 1 | atar
# Processing Record 23 of Set 1 | damara
# Processing Record 24 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 1 | andijon
# Processing Record 26 of Set 1 | vao
# Processing Record 27 of Set 1 | kloulklubed
# Processing Record 28 of Set 1 | cidreira
# Processing Record 29 of Set 1 | omboue
# Processing Record 30 of Set 1 | muros
# Processing Record 31 of Set 1 | port hueneme
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | puerto ayora
# Processing Record 34 of Set 1 | chara
# Processing Record 35 of Set 1 | poya
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | tuktoyaktuk
# Processing Record 38 of Set 1 | los llanos de aridane
# Processing Record 39 of Set 1 | lebu
# Processing Record 40 of Set 1 | yaan
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | broken hill
# Processing Record 43 of Set 1 | mayor pablo lagerenza
# Processing Record 44 of Set 1 | ballina
# Processing Record 45 of Set 1 | bluff
| illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 4 | broome
# Processing Record 32 of Set 4 | mchinji
# Processing Record 33 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 35 of Set 4 | nantucket
# Processing Record 36 of Set 4 | sikonge
# Processing Record 37 of Set 4 | ketchikan
# Processing Record 38 of Set 4 | asfi
# Processing Record 39 of Set 4 | vila franca do campo
# Processing Record 40 of Set 4 | bengkulu
# Processing Record 41 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 42 of Set 4 | teya
# Processing Record 43 of Set 4 | ajdabiya
# Processing Record 44 of Set 4 | bathsheba
# Processing Record 45 of Set 4 | bethel
# Processing Record 46 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 47 of Set 4 | batemans bay
# Processing Record 48 of Set 4 | tonj
# Processing Record 49 of Set 4 | aksarka
# Processing Record 50 of Set 4 | kushima
# Processing Record 1 of Set 5 | pehowa
# Processing Record 2 of Set 5 | vestmanna
# Processing Record 3 of Set 5 | shalakusha
# Processing Record 4 of Set 5 | vestmannaeyjar
# Processing Record 5 of Set 5 | sao filipe
# Processing Record 6 of Set 5 | shkotovo-26
# City not found. Skipping...
# Processing Record 7 of Set 5 | mangai
# Processing Record 8 of Set 5 | ciudad bolivar
# Processing Record 9 of Set 5 | pandan
# Processing Record 10 of Set 5 | great bend
# Processing Record 11 of Set 5 | ponta do sol
# Processing Record 12 of Set 5 | nanortalik
# Processing Record 13 of Set 5 | salalah
# Processing Record 14 of Set 5 | aravankadu
# Processing Record 15 of Set 5 | havoysund
# Processing Record 16 of Set 5 | tasiilaq
# Processing Record 17 of Set 5 | ilulissat
# Processing Record 18 of Set 5 | cimarron hills
# Processing Record 19 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 5 | portland
# Processing Record 21 of Set 5 | ust-maya
# Processing Record 22 of Set 5 | arraial do cabo
# Processing Record 23 of Set 5 | hami
# Processing Record 24 of Set 5 | fortuna
# Processing Record 25 of Set 5 | manokwari
# Processing Record 26 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 5 | faanui
# Processing Record 28 of Set 5 | upernavik
# Processing Record 29 of Set 5 | ormoz
# Processing Record 30 of Set 5 | vostok
# Processing Record 31 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 5 | lakes entrance
# Processing Record 33 of Set 5 | ibra
# Processing Record 34 of Set 5 | boysun
# Processing Record 35 of Set 5 | srednekolymsk
# Processing Record 36 of Set 5 | mtwara
# Processing Record 37 of Set 5 | camana
# Processing Record 38 of Set 5 | toulepleu
# City not found. Skipping...
# Processing Record 39 of Set 5 | asyut
# Processing Record 40 of Set 5 | ahipara
# Processing Record 41 of Set 5 | klaksvik
# Processing Record 42 of Set 5 | ashqelon
# Processing Record 43 of Set 5 | norman wells
# Processing Record 44 of Set 5 | dudinka
# Processing Record 45 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 46 of Set 5 | cherskiy
# Processing Record 47 of Set 5 | kourou
# Processing Record 48 of Set 5 | sabha
# Processing Record 49 of Set 5 | avera
# Processing Record 50 of Set 5 | aksha
# Processing Record 1 of Set 6 | college
# Processing Record 2 of Set 6 | thompson
# Processing Record 3 of Set 6 | agudos
# Processing Record 4 of Set 6 | saint-philippe
# Processing Record 5 of Set 6 | kahului
# Processing Record 6 of Set 6 | oromocto
# Processing Record 7 of Set 6 | thunder bay
# Processing Record 8 of Set 6 | kalmunai
# Processing Record 9 of Set 6 | kirakira
# Processing Record 10 of Set 6 | bonthe
# Processing Record 11 of Set 6 | christchurch
# Processing Record 12 of Set 6 | ahumada
# City not found. Skipping...
# Processing Record 13 of Set 6 | vladaia
# Processing Record 14 of Set 6 | sangar
# Processing Record 15 of Set 6 | lavrentiya
# Processing Record 16 of Set 6 | chokurdakh
# Processing Record 17 of Set 6 | libertador general san martin
# Processing Record 18 of Set 6 | ajaccio
# Processing Record 19 of Set 6 | san pedro
# Processing Record 20 of Set 6 | nemuro
# Processing Record 21 of Set 6 | vagur
# Processing Record 22 of Set 6 | esperance
# Processing Record 23 of Set 6 | richards bay
# Processing Record 24 of Set 6 | grants
# Processing Record 25 of Set 6 | la asuncion
# Processing Record 26 of Set 6 | kant
# Processing Record 27 of Set 6 | tiksi
# Processing Record 28 of Set 6 | harboore
# Processing Record 29 of Set 6 | vilyuysk
# Processing Record 30 of Set 6 | ereymentau
# Processing Record 31 of Set 6 | staryy nadym
# Processing Record 32 of Set 6 | mogocha
# Processing Record 33 of Set 6 | manavalakurichi
# Processing Record 34 of Set 6 | grand gaube
# Processing Record 35 of Set 6 | gorontalo
# Processing Record 36 of Set 6 | flinders
# Processing Record 37 of Set 6 | vila
# Processing Record 38 of Set 6 | hargeysa
# Processing Record 39 of Set 6 | ribeira grande
# Processing Record 40 of Set 6 | mahebourg
# Processing Record 41 of Set 6 | lithakia
# Processing Record 42 of Set 6 | bababe
# City not found. Skipping...
# Processing Record 43 of Set 6 | gat
# Processing Record 44 of Set 6 | khatauli
# Processing Record 45 of Set 6 | necochea
# Processing Record 46 of Set 6 | bontang
# Processing Record 47 of Set 6 | manzhouli
# Processing Record 48 of Set 6 | kodinsk
# Processing Record 49 of Set 6 | puerto escondido
# Processing Record 50 of Set 6 | kinablangan
# Processing Record 1 of Set 7 | rognan
# Processing Record 2 of Set 7 | nishihara
# Processing Record 3 of Set 7 | purpe
# Processing Record 4 of Set 7 | fare
# Processing Record 5 of Set 7 | cockburn town
# Processing Record 6 of Set 7 | bogorodskoye
# Processing Record 7 of Set 7 | ust-shonosha
# Processing Record 8 of Set 7 | yar-sale
# Processing Record 9 of Set 7 | jawa
# Processing Record 10 of Set 7 | point pleasant
# Processing Record 11 of Set 7 | cayenne
# Processing Record 12 of Set 7 | luis correia
# Processing Record 13 of Set 7 | san julian
# Processing Record 14 of Set 7 | balykshi
# Processing Record 15 of Set 7 | chumikan
# Processing Record 16 of Set 7 | coihaique
# Processing Record 17 of Set 7 | chicama
# Processing Record 18 of Set 7 | isangel
# Processing Record 19 of Set 7 | weatherford
# Processing Record 20 of Set 7 | erzin
# Processing Record 21 of Set 7 | kaitangata
# Processing Record 22 of Set 7 | hashtrud
# Processing Record 23 of Set 7 | beringovskiy
# Processing Record 10 of Set 10 | nong khai
# Processing Record 11 of Set 10 | sioux lookout
# Processing Record 12 of Set 10 | iranshahr
# Processing Record 13 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 14 of Set 10 | luganville
# Processing Record 15 of Set 10 | rawson
# Processing Record 16 of Set 10 | saint-georges
# Processing Record 17 of Set 10 | kralendijk
# Processing Record 18 of Set 10 | castro
# Processing Record 19 of Set 10 | viedma
# Processing Record 20 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 21 of Set 10 | normandin
# Processing Record 22 of Set 10 | deputatskiy
# Processing Record 23 of Set 10 | kochi
# Processing Record 24 of Set 10 | svetlogorsk
# Processing Record 25 of Set 10 | mokshan
# Processing Record 26 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 27 of Set 10 | zapolyarnyy
# Processing Record 28 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 30 of Set 10 | kariba
# Processing Record 31 of Set 10 | loa janan
# Processing Record 32 of Set 10 | porto torres
# Processing Record 33 of Set 10 | muriwai beach
# Processing Record 34 of Set 10 | guaira
# Processing Record 35 of Set 10 | shingu
# Processing Record 36 of Set 10 | san jose
# Processing Record 37 of Set 10 | lagoa
# Processing Record 38 of Set 10 | pindobacu
# Processing Record 39 of Set 10 | nanae
# Processing Record 40 of Set 10 | nerchinskiy zavod
# Processing Record 41 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 42 of Set 10 | albanel
# Processing Record 43 of Set 10 | gigmoto
# Processing Record 44 of Set 10 | hamilton
# Processing Record 45 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 46 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 47 of Set 10 | bullhead city
# Processing Record 48 of Set 10 | iralaya
# Processing Record 49 of Set 10 | helena
# Processing Record 50 of Set 10 | sao joao da barra
# Processing Record 1 of Set 11 | suez
# Processing Record 2 of Set 11 | gornyy
# Processing Record 3 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 4 of Set 11 | bandarbeyla
# Processing Record 5 of Set 11 | agadir
# Processing Record 6 of Set 11 | truth or consequences
# Processing Record 7 of Set 11 | vostochnyy
# Processing Record 8 of Set 11 | general pico
# Processing Record 9 of Set 11 | kosh-agach
# Processing Record 10 of Set 11 | la arena
# Processing Record 11 of Set 11 | grootfontein
# Processing Record 12 of Set 11 | tomatlan
# Processing Record 13 of Set 11 | goderich
# Processing Record 14 of Set 11 | alice springs
# Processing Record 15 of Set 11 | conceicao do araguaia
# Processing Record 16 of Set 11 | dolinsk
# Processing Record 17 of Set 11 | chapais
# Processing Record 18 of Set 11 | havre-saint-pierre
# Processing Record 19 of Set 11 | pangnirtung
# Processing Record 20 of Set 11 | ondangwa
# Processing Record 21 of Set 11 | jumla
# Processing Record 22 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 23 of Set 11 | mehamn
# Processing Record 24 of Set 11 | genhe
# Processing Record 25 of Set 11 | vanimo
# Processing Record 26 of Set 11 | kaoma
# Processing Record 27 of Set 11 | pemangkat
# Processing Record 28 of Set 11 | chadan
# Processing Record 29 of Set 11 | husavik
# Processing Record 30 of Set 11 | kjopsvik
# Processing Record 31 of Set 11 | beloha
# Processing Record 32 of Set 11 | leningradskiy
# Processing Record 33 of Set 11 | tsaratanana
# Processing Record 34 of Set 11 | carballo
# Processing Record 35 of Set 11 | lingyuan
# Processing Record 36 of Set 11 | demyanovo
# Processing Record 37 of Set 11 | praya
# Processing Record 38 of Set 11 | ossora
# Processing Record 39 of Set 11 | yuli
# Processing Record 40 of Set 11 | kitob
# Processing Record 41 of Set 11 | longyearbyen
# Processing Record 42 of Set 11 | abu samrah
# Processing Record 43 of Set 11 | el prat de llobregat
# Processing Record 44 of Set 11 | cairo
# Processing Record 45 of Set 11 | hun
# Processing Record 46 of Set 11 | tabuk
# Processing Record 47 of Set 11 | marsciano
# Processing Record 48 of Set 11 | nhulunbuy
# Processing Record 49 of Set 11 | taminango
# Processing Record 50 of Set 11 | klyuchi
# Processing Record 1 of Set 12 | eldorado
# Processing Record 2 of Set 12 | aix-les-bains
# Processing Record 3 of Set 12 | kattivakkam
# Processing Record 4 of Set 12 | pafos
# Processing Record 5 of Set 12 | monaragala
# Processing Record 6 of Set 12 | almeirim
# Processing Record 7 of Set 12 | hualmay
# Processing Record 8 of Set 12 | bondo
# Processing Record 9 of Set 12 | anadyr
# Processing Record 10 of Set 12 | itarema
# Processing Record 11 of Set 12 | buala
# Processing Record 12 of Set 12 | penzance
# Processing Record 13 of Set 12 | namatanai
# Processing Record 14 of Set 12 | poum
# Processing Record 15 of Set 12 | newport
# Processing Record 16 of Set 12 | port macquarie
# Processing Record 17 of Set 12 | naze
# Processing Record 18 of Set 12 | aromashevo
# Processing Record 19 of Set 12 | santa maria del oro
# Processing Record 20 of Set 12 | galesong
# Processing Record 21 of Set 12 | maldonado
# Processing Record 22 of Set 12 | sechura
# Processing Record 23 of Set 12 | ugoofaaru
# Processing Record 24 of Set 12 | morehead
# Processing Record 25 of Set 12 | myski
# Processing Record 26 of Set 12 | bahia blanca
# Processing Record 27 of Set 12 | tsumeb
# Processing Record 28 of Set 12 | anticala
# Processing Record 29 of Set 12 | mayo
# Processing Record 30 of Set 12 | kawalu
# Processing Record 31 of Set 12 | edgewater
# Processing Record 32 of Set 12 | arman
# Processing Record 33 of Set 12 | tunduma
# Processing Record 34 of Set 12 | khalkhal
# Processing Record 35 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 36 of Set 12 | lahaina
# Processing Record 37 of Set 12 | novorzhev
# Processing Record 38 of Set 12 | praia
# Processing Record 39 of Set 12 | bubaque
# Processing Record 40 of Set 12 | simbahan
# Processing Record 41 of Set 12 | smolenka
# Processing Record 42 of Set 12 | puerto suarez
# Processing Record 43 of Set 12 | kewanee
# Processing Record 44 of Set 12 | skibbereen
# Processing Record 45 of Set 12 | malakal
# Processing Record 46 of Set 12 | laramie
# Processing Record 47 of Set 12 | ixtapa
# Processing Record 48 of Set 12 | ziarat
# Processing Record 49 of Set 12 | kars
# Processing Record 50 of Set 12 | kendari
# Processing Record 1 of Set 13 | serchhip
# Processing Record 2 of Set 13 | merke
# Processing Record 3 of Set 13 | pemagatsel
# Processing Record 4 of Set 13 | zhangjiakou
# Processing Record 5 of Set 13 | hearst
# Processing Record 6 of Set 13 | eldikan
# City not found. Skipping...
# ------------------------------------------------
# Data Retrieval Complete
# ------------------------------------------------

# %%
# Length of Latitude and Temprature

len(lat)
len(temp)
# Out:
# 606

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert raw data to dataframe.
city_weather_df = pd.DataFrame({
    "City": cities,
    "Lat": lat,
    "lng": lon,
    "Max Temp": temp_max,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date,
})

# Drop any cities that were skipped because they could not be found using the OpenWeatherMap API.
city_weather_df = city_weather_df.dropna(how="any")
print(city_weather_df.count())
# Out:
# City          550
# Lat           550
# lng           550
# Max Temp      550
# Humidity      550
# Cloudiness    550
# Wind Speed    550
# Country       550
# Date          550
# dtype: int64

# %%
# Export the city data into a .csv file.
city_weather_df.to_csv("./output_data/city_weather_data.csv", index=False)

# Display the DataFrame
weather_df = pd.read_csv("./output_data/city_weather_data.csv")

weather_df.head()
# Out:
#              City      Lat       lng  Max Temp  Humidity  Cloudiness  \
# 0       cape town -33.9258   18.4232     68.00      72.0        20.0
# 1         glencoe -28.1783   30.1470     64.67      65.0        21.0
# 2  severo-kurilsk  50.6789  156.1250     13.86      86.0        92.0
# 3       carnarvon -24.8667  113.6333     77.00      88.0        40.0
# 4         trikala  39.5553   21.7675     30.00      86.0        20.0
#
#    Wind Speed Country          Date
# 0       21.85      ZA  1.611085e+09
# 1        4.21      ZA  1.611085e+09
# 2       23.60      RU  1.611085e+09
# 3       17.27      AU  1.611085e+09
# 4        2.89      GR  1.611085e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %% [markdown]
# Skipping this part as no cities have humidity greater than 100.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
date_time = datetime.date(datetime.now())
# Create a scatter plot for latitude vs max temperature.
x_values = weather_df['Lat']
y_values = weather_df['Max Temp']
fig1, ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f"City Latitude vs Max Temperature {date_time}")
plt.grid()
plt.savefig("./output_data/latitude_vs_temperature.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# The above scatter plot showcase the relationship between Latitude at x-axis vs Max Temperature (F) at the y-axis. This result indicates that there is a higher temrature for the cities that found near to the equater (Latitude 0),however when you go farther from the equator towrads to the north and south the temprature will decrease.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create a scatter plot for latitude vs humidity.
x_values = weather_df['Lat']
y_values = weather_df['Humidity']
fig1, ax1 = plt.subplots(figsize=(10, 8))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs Humidity {date_time}')
plt.grid()
plt.savefig("./output_data/latitude_vs_humidity.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# The above scatter plot displayed the relationship between Humidity (%) vs. Latitude.From the result we can infer that humidity is fairly distributed throughout the plot, so we can say that high humidity occur for both cities found farther or near to the equator.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create a scatter plot for latitude vs cloudiness.
x_values = weather_df['Lat']
y_values = weather_df['Cloudiness']
fig1, ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs Cloudiness {date_time}')
plt.grid()
plt.savefig("./output_data/latitude_vs_cloudiness.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# The above scatter plot showed the relationship between the cities cloudness, and latitude. From this result we can tell that the data is evenly distributed, and there is no difference in Cloudiness when the cities farther or nearer to the equater

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create a scatter plot for latitude vs wind speed.
x_values = weather_df['Lat']
y_values = weather_df['Wind Speed']
fig1, ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs Wind Speed {date_time}')
plt.grid()
plt.savefig("./output_data/latitude_vs_wind_speed.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# The above scatter plot showed the relationship between wind speed (mph), and latitude. The plot displayed the lower wind speed when the cities closer to the equater (latitude 0) and somehow the wind speed increase for the cities farther from the equater.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def createLinearRegressionPlot(x_values, y_values, x_label, y_label, hemisphere, line_placement, ylim=None):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    # Get regression values
    regress_values = x_values * slope + intercept
    
    # Create line equation string
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    fig1, ax1 = plt.subplots(figsize=(10,8))
    plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
    plt.xlabel(x_label,fontsize = 14)
    plt.ylabel(y_label,fontsize = 14)
    if ylim is not None:
        plt.ylim(0, ylim)
    today = datetime.date(datetime.now())
    plt.title(f"{hemisphere} Hemisphere - {x_label} vs {y_label} {today}",fontsize = 15)
    plt.annotate(line_eq,xy=(10, 50),fontsize=22,xycoords='data',xytext=(0.4, 0.4), textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
    plt.annotate(line_eq,xy=(-50, 40),fontsize=22,xycoords='data',xytext=(0.4, 0.3), textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
    plt.annotate(line_eq,xy=(10, 25),fontsize=22,xycoords='data',xytext=(0.4, 0.4), textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
    # Print r square value
    print(f"The r-squared is: {rvalue**2}")
    correlation = st.pearsonr(x_values,y_values)
    print(f"The correlation between both factors is {round(correlation[0],2)}")
    return plt.plot(x_values,regress_values,"r-")

# %%
# Create Northern and Southern Hemisphere DataFrames

northern_hemisphere_weather_df = weather_df.loc[weather_df["Lat"] >= 0]
southern_hemisphere_weather_df = weather_df.loc[weather_df["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs max temp (northern hemisphere)
x_values = northern_hemisphere_weather_df['Lat']
y_values = northern_hemisphere_weather_df['Max Temp']
createLinearRegressionPlot(x_values, y_values, "Lat", "Max Temp (F)", "Northern",(0, 0))
plt.savefig("./output_data/Northern_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.6986819647213042
# The correlation between both factors is -0.84

# %% [markdown]
# The above plot is a linear regression model between Maximum tempreture and latitude for Northern Hemisphere cities. The result from the data showed that there is a strong, negative correlation between Maximum tempreture and latitude. These means when we go farther away from the equater(latitude 0) the maximum Temperature (F) will decrease.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs cloudiness (southern hemisphere)
x_values = southern_hemisphere_weather_df['Lat']
y_values = southern_hemisphere_weather_df['Cloudiness']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Cloudiness(%)", "Southern",(-45, 60))

plt.savefig("./output_data/southern_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.14350027311836694
# The correlation between both factors is 0.38

# %% [markdown]
# The above plot is a linear regression model between Maximum tempreture and latitude for Southern Hemisphere cities.The result from the data showed that there is a very week correlation between Maximum Tempreture and latitude in the Southern Hemisphere cities.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs humditiy (northern hemisphere)
x_values = northern_hemisphere_weather_df['Lat']
y_values = northern_hemisphere_weather_df['Humidity']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Humidity (%)", "Northern",(40, 20))
plt.savefig("./output_data/Northern_Hemisphere_Humidity_Latitude_Linear.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.18236042588101128
# The correlation between both factors is 0.43

# %% [markdown]
# The above plot is a linear regression model between Humidity (%) and Latitude for Northern Hemisphere cities. The result from the data showed that there is a correlation between Humidity (%) and Latitude in the Northern Hemisphere cities.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs humditiy (southern hemisphere)
x_values1 = southern_hemisphere_weather_df['Lat']
y_values1 = southern_hemisphere_weather_df['Humidity']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Humidity (%)", "Southern",(40, 20), 150)
plt.savefig("./output_data/southern_humudity_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.18236042588101128
# The correlation between both factors is 0.43

# %% [markdown]
# The above plot is a linear regression model between Humidity (%) and Latitude for Southern Hemisphere cities. The result from the data showed that there is a correlation between Humidity (%) and Latitude in the Southern Hemisphere cities.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs cloudiness (northern hemisphere)
x_values = northern_hemisphere_weather_df['Lat']
y_values = northern_hemisphere_weather_df['Cloudiness']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Cloudiness(%)", "Northern",(30, 50))

plt.savefig("./output_data/Northern Hemisphere_Cloudiness_Latitude_Linear.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.08785694754519645
# The correlation between both factors is 0.3

# %% [markdown]
# The above plot is a linear regression model between Cloudiness (%) and Latitude for Northern_Hemisphere cities. The result from the data showed that there is a correlation between Cloudiness (%) and Latitude in the Southern Hemisphere cities.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs cloudiness (southern hemisphere)
x_values = southern_hemisphere_weather_df['Lat']
y_values = southern_hemisphere_weather_df['Cloudiness']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Cloudiness(%)", "Southern",(-45, 60))
plt.savefig("./output_data/Southern_Hemisphere_Cloudiness_Latitude_Linear.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.14350027311836694
# The correlation between both factors is 0.38

# %% [markdown]
# The above plot is a linear regression model between Cloudiness (%) and for Southern Hemisphere cities. The result from the data showed that there is a correlation between Cloudiness (%) and Latitude in the Southern Hemisphere cities.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs wind speed(northern hemisphere)
x_values = northern_hemisphere_weather_df['Lat']
y_values = northern_hemisphere_weather_df['Wind Speed']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Wind Speed (mph)", "Northern",(20, 25))
plt.savefig("./output_data/Northern_Hemisphere_Wind_Speed_Latitude_Lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.000760965836394847
# The correlation between both factors is 0.03

# %% [markdown]
# The above plot is a linear regression model between Wind Speed (mph), and latitude for Northern_Hemisphere cities. The result from the data showed that there is a very week, posetive correlation between Wind Speed (mph (%) and Latitude in the Northern Hemisphere cities.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs wind speed (southern hemisphere)
x_values = southern_hemisphere_weather_df['Lat']
y_values = southern_hemisphere_weather_df['Wind Speed']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Wind Speed (mph)", "Southern",(-40, 25), ylim=40)
plt.savefig("./output_data/Southern_Hemisphere_Wind_Speed_Latitude_Linear_Regression.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.07915027842315889
# The correlation between both factors is -0.28

# %% [markdown]
# The above plot is a linear regression model between Wind Speed (mph), and latitude for Southern Hemisphere. The result from the data showed that there is a very week, negative correlation between Wind Speed (mph (%) and Latitude in the Northern Hemisphere cities.
